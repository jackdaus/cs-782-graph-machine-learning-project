# %% [markdown]
# # Training with many subsets
#
# Next, we will take our method or constructing many subset and train a model with this more complicated data! This is a lot more interesting the datasets we previosuly trained on.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)
# Choose device (cuda if available, else cpu)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Selected device:", device)
# Out:
# 2.9.0+cu128
# Selected device: cuda

# %% [markdown]
# # Load Data

# %%
## Load the colmap data
import pycolmap
import pathlib
import utils.subset
import random
import utils.loaders

# Load the Colmap data into a torch dataset
model_path = pathlib.Path('./output/01_nerf/02_lego_large/1762043798762/0')
reconstruction = pycolmap.Reconstruction(model_path)

# %%
# Define the directory where our source images are from
image_dir = pathlib.Path('data', '01_nerf', '02_lego_large')

random.seed(42) # for reproducibility

graph_a_list = []
graph_b_list = []
labels = []
for i in range(100):
    # Create a random subset using distance based heuristic
    a_ids, b_ids = utils.subset.create_image_subsets_from_distance(reconstruction, 15, random_captains=True)
    # Create a PyG graph Dataset for each subset
    graph_a = utils.loaders.load_reconstruction_to_graph(reconstruction, image_dir, a_ids)
    graph_b = utils.loaders.load_reconstruction_to_graph(reconstruction, image_dir, b_ids)
    # Randomly perturb the transforms. We uniformly sample 3 values from the range [-10.0, 10.0]
    perturbation = torch.empty(3).uniform_(-10.0,10.0)
    graph_b.x[:,:3] = graph_b.x[:,:3] + perturbation
    # TODO perturb graph_a too with a different value, and then add perturbations to derive label
    graph_a_list.append(graph_a)
    graph_b_list.append(graph_b)
    labels.append(perturbation)

# %%
from utils.loaders import GraphPairDataset

# Create the Dataset!
#TODO can I save these to disk?
dataset = GraphPairDataset(graph_a_list, graph_b_list, labels)
dataset
# Out:
# GraphPairDataset(100)

# %% [markdown]
# # Aside: Example of saving and loading this precomputed dataset

# %%
dataset.save("data/data.pt")

# %%
from utils.loaders import GraphPairDataset

dataset = GraphPairDataset.load("data/data.pt")

# %% [markdown]
# # Training Loop

# %% [markdown]
# ## Construct dataloaders

# %%
from torch_geometric.loader import DataLoader
from torch.utils.data import random_split

# Split our dataset based on 80-20 training-validation split
dataset_size = len(dataset)
train_size = int(dataset_size * 0.8)
val_size = dataset_size - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# And we create a distinct DataLoader for each dataset train and val
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## Train

# %%
import numpy as np
from models import SiameseGCN_v1
from tqdm import tqdm

torch.manual_seed(43)
random.seed(43)

# Define model
# To get our number of node features, let's check the first Data and the first graph_a
num_node_features = dataset.g_list_1[0].num_features
model = SiameseGCN_v1(num_node_features)
model.to(device)
# Out:
# SiameseGCN_v1(
#   (sisterA): GraphEmbeddingGCN_v1(
#     (conv1): GCNConv(30, 4)
#     (conv2): GCNConv(4, 4)
#     (linear): Linear(in_features=4, out_features=4, bias=True)
#   )
#   (sisterB): GraphEmbeddingGCN_v1(
#     (conv1): GCNConv(30, 4)
#     (conv2): GCNConv(4, 4)
#     (linear): Linear(in_features=4, out_features=4, bias=True)
#   )
#   (linear1): Linear(in_features=8, out_features=8, bias=True)
#   (linear2): Linear(in_features=8, out_features=8, bias=True)
#   (mlp): Sequential(
#     (0): Linear(in_features=8, out_features=8, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=8, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=8, out_features=3, bias=True)
#   )
# )

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.8)
criterion = torch.nn.MSELoss()

num_epochs = 800

# Keep track of loss
epoch_losses_train = []
epoch_losses_val = np.full(num_epochs, np.nan)  # one slot per epoch
with tqdm(range(num_epochs),desc=f"Training progress") as pbar:
    for epoch in pbar:
        model.train()
        train_loss = 0.0
        for batch in train_loader:
            # Move data to the GPU
            graph_a_batch = batch[0].to(device)
            graph_b_batch = batch[1].to(device)
            label_batch   = batch[2].to(device)
            optimizer.zero_grad()
            out = model(graph_a_batch, graph_b_batch)
            loss = criterion(out, label_batch)
            # Compute gradient
            loss.backward()
            # update the weights
            optimizer.step()
            train_loss += loss.item()
        avg_loss = train_loss / len(train_loader)
        epoch_losses_train.append(avg_loss)
        pbar.set_postfix({'loss': f'{avg_loss:.4f}' })
        # learning rate decay
        scheduler.step()

        # Validation
        if epoch % 10 == 0:
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch in val_loader:
                    graph_a_batch = batch[0].to(device)
                    graph_b_batch = batch[1].to(device)
                    label_batch   = batch[2].to(device)
                    out = model(graph_a_batch, graph_b_batch)
                    loss = criterion(out, label_batch)
                    val_loss += loss.item()
            epoch_losses_val[epoch] = val_loss / len(val_loader)
# Out:
# Training progress:   0%|          | 0/800 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 15
#      13 model.train()
#      14 train_loss = 0.0
# ---> 15 for batch in train_loader:
#      16     # Move data to the GPU
#      17     graph_a_batch = batch[0].to(device)
#      18     graph_b_batch = batch[1].to(device)
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch\utils\data\dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch_geometric\loader\dataloader.py:47, in Collater.__call__(self, batch)
#      45     return type(elem)(*(self(s) for s in zip(*batch)))
#      46 elif isinstance(elem, Sequence) and not isinstance(elem, str):
# ---> 47     return [self(s) for s in zip(*batch)]
#      49 raise TypeError(f"DataLoader found invalid type: '{type(elem)}'")
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch_geometric\loader\dataloader.py:27, in Collater.__call__(self, batch)
#      25 elem = batch[0]
#      26 if isinstance(elem, BaseData):
# ---> 27     return Batch.from_data_list(
#      28         batch,
#      29         follow_batch=self.follow_batch,
#      30         exclude_keys=self.exclude_keys,
#      31     )
#      32 elif isinstance(elem, torch.Tensor):
#      33     return default_collate(batch)
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch_geometric\data\batch.py:97, in Batch.from_data_list(cls, data_list, follow_batch, exclude_keys)
#      82 @classmethod
#      83 def from_data_list(
#      84     cls,
#    (...)     87     exclude_keys: Optional[List[str]] = None,
#      88 ) -> Self:
#      89     r"""Constructs a :class:`~torch_geometric.data.Batch` object from a
#      90     list of :class:`~torch_geometric.data.Data` or
#      91     :class:`~torch_geometric.data.HeteroData` objects.
#    (...)     95     Will exclude any keys given in :obj:`exclude_keys`.
#      96     """
# ---> 97     batch, slice_dict, inc_dict = collate(
#      98         cls,
#      99         data_list=data_list,
#     100         increment=True,
#     101         add_batch=not isinstance(data_list[0], Batch),
#     102         follow_batch=follow_batch,
#     103         exclude_keys=exclude_keys,
#     104     )
#     106     batch._num_graphs = len(data_list)  # type: ignore
#     107     batch._slice_dict = slice_dict  # type: ignore
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch_geometric\data\collate.py:109, in collate(cls, data_list, increment, add_batch, follow_batch, exclude_keys)
#     106     continue
#     108 # Collate attributes into a unified representation:
# --> 109 value, slices, incs = _collate(attr, values, data_list, stores,
#     110                                increment)
#     112 # If parts of the data are already on GPU, make sure that auxiliary
#     113 # data like `batch` or `ptr` are also created on GPU:
#     114 if isinstance(value, Tensor) and value.is_cuda:
#
# File ~\source\colmap-experiments\.venv\Lib\site-packages\torch_geometric\data\collate.py:203, in _collate(key, values, data_list, stores, increment)
#     200         shape[cat_dim] = int(slices[-1])
#     201     out = elem.new(storage).resize_(*shape)
# --> 203 value = torch.cat(values, dim=cat_dim or 0, out=out)
#     205 if increment and isinstance(value, Index) and values[0].is_sorted:
#     206     # Check whether the whole `Index` is sorted:
#     207     if (value.diff() >= 0).all():
#
# RuntimeError: Expected all tensors to be on the same device, but got tensors is on cuda:0, different from other tensors on cpu (when checking argument in method wrapper_CUDA_cat)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(epoch_losses_train)
plt.plot(epoch_losses_val, marker='o')
plt.show()

# %% [markdown]
# # Visualize Prediction

# %%
# Let's grab a random datum for our dataset
# sample = val_dataset[2]
sample = train_dataset[4]
model.eval()
graph_a = sample[0].to(device)
graph_b = sample[1].to(device)
label   = sample[2].to(device)
with torch.no_grad():
    pred = model(graph_a, graph_b)

pred.to('cpu')
# Out:
# tensor([[-1.6725,  3.7018, -8.3038]])

# %%
# Create data to viz the predictions
predicted_graph = graph_b.clone()
predicted_graph.x[:,:3] = predicted_graph.x[:,:3] - pred

true_graph = graph_b.clone()
true_graph.x[:,:3] = true_graph.x[:,:3] - label

# %%
# Plat example from training data prediction
import utils.vis
# visualize the original data
utils.vis.plot_3D_graph(graph_a, graph_b)

# %%
# Display pairs of data
import utils.vis
utils.vis.plot_3D_graph_subplots([(graph_a, graph_b), (graph_a, predicted_graph), (graph_a, true_graph)], ["Input","Prediction","Truth"])

# %%
# Display all data in one plot
utils.vis.plot_many_3D_graphs([graph_a, graph_b, predicted_graph, true_graph], ["Graph A","Graph B (Input)","Graph B (Prediction)", "Graph B (Truth)"])
