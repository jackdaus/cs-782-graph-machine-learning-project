# %%
import pycolmap

# %%
keypoint = pycolmap.FeatureKeypoint()

# %%
keypoint
# Out:
# FeatureKeypoint(x=0, y=0)

# %%
keypoint.x = 100

# %%
keypoint
# Out:
# FeatureKeypoint(x=100, y=0)

# %%
match = pycolmap.FeatureMatch(point2D_idx1=0, point2D_idx2=1)

# %%
match
# Out:
# FeatureMatch(idx1=0, idx2=1)
